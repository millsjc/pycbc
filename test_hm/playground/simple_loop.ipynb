# %%
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
from numba import njit

# %%
@njit
def three_det_sum_jit(t1, t2, t3, t2_coinc_window, t3_coinc_window):
    N = len(t1)
    temp = array([
        t1[i] + t2[j] + t3[k]
            for i in range(N)
                for j in range(max(i-t2_coinc_window, 0), min(N, i+t2_coinc_window+1))
                    for k in range(max(i-t3_coinc_window, 0), min(N, i+t3_coinc_window+1))
                ])
    return temp

def three_det_sum(t1, t2, t3, t2_coinc_window, t3_coinc_window):
    N = len(t1)
    temp = array([
        t1[i] + t2[j] + t3[k]
            for i in range(N)
                for j in range(max(i-t2_coinc_window, 0), min(N, i+t2_coinc_window+1))
                    for k in range(max(i-t3_coinc_window, 0), min(N, i+t3_coinc_window+1))
                ])
    return temp

# %%
seglen * srate
# Out:
# 262144

# %%
srate = 512
seglen = 16
N = seglen * srate
# N=int(2e2)
print(N)
t1 = 9+chisquare(4,N)
t2 = 9+chisquare(4,N)
t3 = 9+chisquare(4,N)
t2_coinc_window = int(ceil(10/1000.0 * srate)) #int(83 / 2.)
t3_coinc_window = int(ceil(27.3/1000.0 * srate)) #int(230 / 2.)
# Out:
# 8192

# %%
shape(array(temp))
# Out:
# (3084954,)

# %%
# %time temp = three_det_sum_jit(t1, t2, t3, t2_coinc_window, t3_coinc_window)
# Out:
# CPU times: user 23.8 ms, sys: 18.1 ms, total: 41.9 ms
# Wall time: 47.2 ms

# %%
# %time temp = three_det_sum(t1, t2, t3, t2_coinc_window, t3_coinc_window)
# Out:
# CPU times: user 1.7 s, sys: 26.6 ms, total: 1.73 s
# Wall time: 1.73 s

# %%
sum(temp>7**2)
# Out:
# 0.04275392524663054

# %%
degrees(pi/3)
# Out:
# 59.99999999999999

# %%
_t = temp

# %%
len(temp[80])
# Out:
# 13

# %%
sum(array(temp) > 7**2)
# Out:
# /var/folders/2n/44xg31f92bd49rgkf9bsy4j80000gq/T/ipykernel_79644/4075904114.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   sum(array(temp) > 7**2)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 sum(array(temp) > 7**2)
#
# TypeError: '>' not supported between instances of 'list' and 'int'
