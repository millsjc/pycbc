# %%
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
import h5py

# %%
f = h5py.File("../bank/full-correct-tau-xhm-spinning-2filter-listharms.hdf", "r")

# %%
f["inclination"]
# Out:
# <HDF5 dataset "inclination": shape (17751,), type "<f8">

# %%
min(array(f["mass1"]) + array(f["mass2"]))
# Out:
# 100.0031900428068

# %%
plot(array(f["mass1"]), array(f["mass2"]), "rx")
plot([100, 200, 300, 400, 500], [100, 200, 300, 400, 500])
# plot(array(f["mass1"]), array(f["mass2"]), "rx")
