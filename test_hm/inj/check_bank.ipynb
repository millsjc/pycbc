# %%
# %pylab inline
import h5py
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
with h5py.File("full-correct-tau-xhm-spinning-2filter.hdf", "r") as f:
    bank = {k: array(v) for k,v in f.items()}

# %%
with h5py.File("bbh-3dets_snr.hdf", "r+") as f:
    injections = {k: array(v) for k,v in f.items()}

# %%
bank["mode_array"][0]
# Out:
# array([[ 4,  4],
#        [ 4, -4]])

# %%
for p in ["mass1", "mass2", "spin1z", "spin2z"]:
    hist(bank[p], histtype="step", bins=30, density=True, lw=4)
    xlabel(p)
    show()
hist(bank["mass1"] + bank["mass2"], histtype="step", bins=30, density=True, lw=4)
xlabel("total mass")
show()
hist(bank["mass1"] / bank["mass2"], histtype="step", bins=30, density=True, lw=4)
xlabel("mass ratio")
show()
#     hist(bank[p], histtype="step", bins=30, density=True)
